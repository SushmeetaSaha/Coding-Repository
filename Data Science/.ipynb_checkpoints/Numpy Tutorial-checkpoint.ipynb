# %%
import numpy as np

# %%
arr = np.array([1,3,4,4],dtype = int64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 arr = np.array([1,3,4,4],dtype=int64)
#
# NameError: name 'int64' is not defined
